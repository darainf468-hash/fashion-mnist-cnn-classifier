# %%
# --- 1. Import Libraries ---
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

print("TensorFlow Version:", tf.__version__)

# --- 2. Load Data ---
print("\n--- Loading Fashion-MNIST Dataset ---")
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.fashion_mnist.load_data()

# Define the class names for plotting and reporting
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# --- 3. Preprocess Data ---
print("\n--- Preprocessing Data ---")
# Normalize pixel values to be between 0 and 1
train_images = train_images / 255.0
test_images = test_images / 255.0

# Reshape images to add a channel dimension (28, 28) -> (28, 28, 1)
train_images = train_images.reshape((train_images.shape[0], 28, 28, 1))
test_images = test_images.reshape((test_images.shape[0], 28, 28, 1))

print(f"Reshaped training images shape: {train_images.shape}")
print(f"Reshaped testing images shape: {test_images.shape}")


# --- 4. Build the Improved CNN Model ---
print("\n--- Building Improved CNN Model with Data Augmentation and Dropout ---")

# Define the Data Augmentation layer
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal", input_shape=(28, 28, 1)),
    layers.RandomRotation(0.1),
])

model = models.Sequential([
    data_augmentation,
    layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(10, activation='softmax')
])

# Display the model's architecture
model.summary()


# --- 5. Compile the Model ---
print("\n--- Compiling Model ---")
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])


# --- 6. Train the Model with Early Stopping ---
print("\n--- Training Model with Early Stopping ---")
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
EPOCHS = 50
history = model.fit(train_images, train_labels,
                    epochs=EPOCHS,
                    validation_data=(test_images, test_labels),
                    callbacks=[early_stopping],
                    verbose=1)


# --- 7. Evaluate Performance ---
print("\n--- Evaluating Model Performance ---")
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
print(f"\nTest Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc:.4f}")


# --- 8. Visualize Results ---
print("\n--- Generating Predictions and Visualizing Results ---")
predictions = model.predict(test_images)
predicted_labels = np.argmax(predictions, axis=1)

# ADDED BACK: Display a few test images with their predicted and true labels
print("\n--- Displaying Sample Test Predictions ---")
plt.figure(figsize=(12,12))
for i in range(25): # Display 25 predictions
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(test_images[i].reshape(28,28), cmap=plt.cm.binary) # Reshape back for imshow
    true_label = class_names[test_labels[i]]
    predicted_label = class_names[predicted_labels[i]]
    color = 'green' if predicted_labels[i] == test_labels[i] else 'red'
    plt.xlabel(f"True: {true_label}\nPred: {predicted_label}", color=color)
plt.suptitle("Sample Test Predictions (Green=Correct, Red=Incorrect)", fontsize=16)
plt.show()

# Generate and plot Confusion Matrix
print("\n--- Generating Confusion Matrix ---")
cm = confusion_matrix(test_labels, predicted_labels)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# Generate Classification Report
print("\n--- Classification Report ---")
print(classification_report(test_labels, predicted_labels, target_names=class_names))

print("\n--- Project Complete! ---")
# Out:
# TensorFlow Version: 2.19.0
#
# --- Loading Fashion-MNIST Dataset ---
#
# --- Preprocessing Data ---
# Reshaped training images shape: (60000, 28, 28, 1)
# Reshaped testing images shape: (10000, 28, 28, 1)
#
# --- Building Improved CNN Model with Data Augmentation and Dropout ---
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/preprocessing/tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 28, 28, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 14, 14, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 3136)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       401,536 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 421,642 (1.61 MB)
#  Trainable params: 421,642 (1.61 MB)
#  Non-trainable params: 0 (0.00 B)
# --- Compiling Model ---
#
# --- Training Model with Early Stopping ---
# Epoch 1/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 17s 6ms/step - accuracy: 0.6508 - loss: 0.9641 - val_accuracy: 0.8043 - val_loss: 0.5208
# Epoch 2/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.7907 - loss: 0.5687 - val_accuracy: 0.8236 - val_loss: 0.4661
# Epoch 3/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8170 - loss: 0.4999 - val_accuracy: 0.8517 - val_loss: 0.4107
# Epoch 4/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.8348 - loss: 0.4547 - val_accuracy: 0.8603 - val_loss: 0.3800
# Epoch 5/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8413 - loss: 0.4399 - val_accuracy: 0.8632 - val_loss: 0.3791
# Epoch 6/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8495 - loss: 0.4164 - val_accuracy: 0.8692 - val_loss: 0.3708
# Epoch 7/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.8548 - loss: 0.3967 - val_accuracy: 0.8733 - val_loss: 0.3574
# Epoch 8/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - accuracy: 0.8581 - loss: 0.3909 - val_accuracy: 0.8756 - val_loss: 0.3427
# Epoch 9/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.8603 - loss: 0.3812 - val_accuracy: 0.8809 - val_loss: 0.3197
# Epoch 10/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.8622 - loss: 0.3761 - val_accuracy: 0.8795 - val_loss: 0.3259
# Epoch 11/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.8669 - loss: 0.3657 - val_accuracy: 0.8839 - val_loss: 0.3329
# Epoch 12/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8679 - loss: 0.3670 - val_accuracy: 0.8873 - val_loss: 0.3262
# Epoch 13/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8698 - loss: 0.3564 - val_accuracy: 0.8886 - val_loss: 0.3052
# Epoch 14/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8705 - loss: 0.3533 - val_accuracy: 0.8907 - val_loss: 0.3048
# Epoch 15/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8742 - loss: 0.3444 - val_accuracy: 0.8895 - val_loss: 0.3047
# Epoch 16/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8760 - loss: 0.3403 - val_accuracy: 0.8991 - val_loss: 0.2939
# Epoch 17/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8750 - loss: 0.3441 - val_accuracy: 0.8943 - val_loss: 0.2986
# Epoch 18/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8788 - loss: 0.3344 - val_accuracy: 0.8938 - val_loss: 0.3016
# Epoch 19/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.8801 - loss: 0.3322 - val_accuracy: 0.8981 - val_loss: 0.2832
# Epoch 20/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.8800 - loss: 0.3323 - val_accuracy: 0.8933 - val_loss: 0.3052
# Epoch 21/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.8816 - loss: 0.3259 - val_accuracy: 0.9000 - val_loss: 0.2847
# Epoch 22/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.8806 - loss: 0.3262 - val_accuracy: 0.8958 - val_loss: 0.2945
# Epoch 23/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - accuracy: 0.8841 - loss: 0.3198 - val_accuracy: 0.8906 - val_loss: 0.3146
# Epoch 24/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - accuracy: 0.8842 - loss: 0.3237 - val_accuracy: 0.9035 - val_loss: 0.2783
# Epoch 25/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.8811 - loss: 0.3262 - val_accuracy: 0.8980 - val_loss: 0.2870
# Epoch 26/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.8840 - loss: 0.3215 - val_accuracy: 0.9057 - val_loss: 0.2794
# Epoch 27/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.8828 - loss: 0.3194 - val_accuracy: 0.9003 - val_loss: 0.2900
# Epoch 28/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.8842 - loss: 0.3161 - val_accuracy: 0.9032 - val_loss: 0.2829
# Epoch 29/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - accuracy: 0.8873 - loss: 0.3112 - val_accuracy: 0.8955 - val_loss: 0.2908
#
# --- Evaluating Model Performance ---
# 313/313 - 1s - 3ms/step - accuracy: 0.9035 - loss: 0.2783
#
# Test Loss: 0.2783
# Test Accuracy: 0.9035
#
# --- Generating Predictions and Visualizing Results ---
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# --- Displaying Sample Test Predictions ---
# --- Generating Confusion Matrix ---
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#  T-shirt/top       0.84      0.89      0.86      1000
#      Trouser       0.99      0.98      0.99      1000
#     Pullover       0.82      0.88      0.85      1000
#        Dress       0.89      0.90      0.90      1000
#         Coat       0.84      0.82      0.83      1000
#       Sandal       0.98      0.97      0.97      1000
#        Shirt       0.77      0.68      0.72      1000
#      Sneaker       0.94      0.98      0.96      1000
#          Bag       0.98      0.98      0.98      1000
#   Ankle boot       0.98      0.95      0.97      1000
#
#     accuracy                           0.90     10000
#    macro avg       0.90      0.90      0.90     10000
# weighted avg       0.90      0.90      0.90     10000
#
#
# --- Project Complete! ---
